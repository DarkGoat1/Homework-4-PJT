# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Reference the file where the CSV is located
file = "Resources/crime_incident_data2017.csv"
# Import the data into a Pandas DataFrame
df_crime = pd.read_csv(file)
df_crime.head()
# Out:
#                     Address  Case Number Crime Against     Neighborhood  \
# 0                       NaN  17-X4762181        Person              NaN
# 1                       NaN  17-X4757824      Property       Centennial
# 2  200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                       NaN  17-X4748982      Property  Southwest Hills
# 4                       NaN  17-X4748982      Property  Southwest Hills
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# 1                  1    1/20/00           1/1/00        1615
# 2                  1    12/1/03          12/1/03         800
# 3                  1     1/1/10           1/1/10           0
# 4                  1     1/1/10           1/1/10           0
#
#    Offense Category  Offense Count                             Offense Type  \
# 0      Sex Offenses              1                                     Rape
# ...

# %%
# look for missing values
df_crime.count()
# Out:
# Address              37365
# Case Number          41032
# Crime Against        41032
# Neighborhood         39712
# Number of Records    41032
# Occur Date           41032
# Occur Month Year     41032
# Occur Time           41032
# Offense Category     41032
# Offense Count        41032
# Offense Type         41032
# Open Data Lat        36712
# Open Data Lon        36712
# Open Data X          36712
# Open Data Y          36712
# Report Date          41032
# Report Month Year    41032
# dtype: int64

# %%
# drop null rows
df_crimedrop = df_crime.dropna(how='any')

# %%
# verify counts
df_crimedrop.count()
# Out:
# Address              36146
# Case Number          36146
# Crime Against        36146
# Neighborhood         36146
# Number of Records    36146
# Occur Date           36146
# Occur Month Year     36146
# Occur Time           36146
# Offense Category     36146
# Offense Count        36146
# Offense Type         36146
# Open Data Lat        36146
# Open Data Lon        36146
# Open Data X          36146
# Open Data Y          36146
# Report Date          36146
# Report Month Year    36146
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
df_crimedrop['Neighborhood'].value_counts()
# Out:
# Downtown                2666
# Hazelwood               2378
# Lents                   1315
# Old Town/Chinatown      1239
# Powellhurst-Gilbert     1233
# Northwest               1085
# Centennial              1028
# Montavilla               976
# Pearl                    970
# Lloyd                    895
# Buckman West             873
# Parkrose                 822
# Eliot                    689
# Richmond                 664
# Sunnyside                618
# Kerns                    614
# Sellwood-Moreland        602
# Hosford-Abernethy        598
# St Johns                 572
# Cully                    564
# Goose Hollow             553
# Mill Park                522
# Brentwood-Darlington     481
# Buckman East             471
# Foster-Powell            465
# Argay                    463
# Creston-Kenilworth       459
# Madison South            435
# Mt Tabor                 400
# Hayden Island            400
#                         ...
# Southwest Hills          141
# ...

# %%
# Combine similar offenses

# %%
# Create a new DataFrame that looks into a specific neighborhood

dtcrime = df_crimedrop.loc[df_crimedrop["Neighborhood"] == "Downtown", :]
dtcrime.head()
# Out:
#                            Address Case Number Crime Against Neighborhood  \
# 32          500 BLOCK OF SW OAK ST   17-900051      Property     Downtown
# 33  1300 BLOCK OF SW WASHINGTON ST     17-4490      Property     Downtown
# 63        1100 BLOCK OF SW 2ND AVE    17-27849      Property     Downtown
# 86   1000 BLOCK OF SW JEFFERSON ST   17-900855      Property     Downtown
# 95        1100 BLOCK OF SW 2ND AVE     17-5712      Property     Downtown
#
#     Number of Records Occur Date Occur Month Year  Occur Time  \
# 32                  1    1/31/16           1/1/16        2300
# 33                  1     1/3/16           1/1/16        1900
# 63                  1     6/1/16           6/1/16           1
# 86                  1    9/28/16           9/1/16        2000
# 95                  1   10/20/16          10/1/16        1200
#
#        Offense Category  Offense Count              Offense Type  \
# 32     Larceny Offenses              1  Theft From Motor Vehicle
# ...
